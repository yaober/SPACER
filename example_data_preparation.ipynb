# %%
import scanpy as sc
import numpy as np

# %%
adata = sc.read("/work/DPDS/s439765/data4spacer/spatial_transcriptomics/VisiumHD/processed/Colon_Cancer_P5T_cell.h5ad")

# %%
np.random.seed(42)  
n_cells = adata.n_obs
sample_size = int(n_cells * 0.2)

# %%
idx = np.random.choice(n_cells, size=sample_size, replace=False)

# %%
sample_data = adata[idx, :].copy()

# %%
sample_data.write_h5ad('data/example_data.h5ad')
